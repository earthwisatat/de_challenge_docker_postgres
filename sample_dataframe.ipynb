# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
# Reading Excel data

df_foodsales = pd.read_excel('de_challenge_data.xlsx', sheet_name='FoodSales', skiprows=1, usecols='A:I')
df_foodsales
# Out:
#           ID                 Date Region         City  Category  \
# 0    ID07351  2022-01-01 00:00:00   East       Boston      Bars
# 1    ID07352  2022-01-04 00:00:00   East       Boston  Crackers
# 2    ID07353  2022-01-07 00:00:00   West  Los Angeles   Cookies
# 3    ID07354  2022-01-10 00:00:00   East     New York   Cookies
# 4    ID07355  2022-01-13 00:00:00   East       Boston   Cookies
# ..       ...                  ...    ...          ...       ...
# 242  ID07590  2023-12-18 00:00:00   East       Boston   Cookies
# 243  ID07591  2023-12-21 00:00:00   East       Boston   Cookies
# 244  ID07592  2023-12-24 00:00:00   East       Boston  Crackers
# 245  ID07593  2023-12-27 00:00:00   West  Los Angeles      Bars
# 246  ID07594  2023-12-30 00:00:00   West  Los Angeles   Cookies
#
#             Product  Qty UnitPrice TotalPrice
# 0            Carrot   33      1.77      58.41
# 1       Whole Wheat   87      3.49     303.63
# 2    Chocolate Chip   58      1.87     108.46
# 3    Chocolate Chip   82      1.87     153.34
# 4         Arrowroot   38      2.18      82.84
# ..              ...  ...       ...        ...
# 242       Arrowroot   34      2.18      74.12
# 243  Chocolate Chip  245      1.87     458.15
# 244     Whole Wheat   30      3.49      104.7
# 245            Bran   30      1.87       56.1
# 246  Oatmeal Raisin   44      2.84     124.96
#
# [247 rows x 9 columns]

# %%
# Rename columns in case column name is not the same

df_foodsales.columns = ['id', 'date', 'region', 'city', 'category', 'product', 'qty', 'unitprice', 'totalprice']
df_foodsales
# Out:
#           id                 date region         city  category  \
# 0    ID07351  2022-01-01 00:00:00   East       Boston      Bars
# 1    ID07352  2022-01-04 00:00:00   East       Boston  Crackers
# 2    ID07353  2022-01-07 00:00:00   West  Los Angeles   Cookies
# 3    ID07354  2022-01-10 00:00:00   East     New York   Cookies
# 4    ID07355  2022-01-13 00:00:00   East       Boston   Cookies
# ..       ...                  ...    ...          ...       ...
# 242  ID07590  2023-12-18 00:00:00   East       Boston   Cookies
# 243  ID07591  2023-12-21 00:00:00   East       Boston   Cookies
# 244  ID07592  2023-12-24 00:00:00   East       Boston  Crackers
# 245  ID07593  2023-12-27 00:00:00   West  Los Angeles      Bars
# 246  ID07594  2023-12-30 00:00:00   West  Los Angeles   Cookies
#
#             product  qty unitprice totalprice
# 0            Carrot   33      1.77      58.41
# 1       Whole Wheat   87      3.49     303.63
# 2    Chocolate Chip   58      1.87     108.46
# 3    Chocolate Chip   82      1.87     153.34
# 4         Arrowroot   38      2.18      82.84
# ..              ...  ...       ...        ...
# 242       Arrowroot   34      2.18      74.12
# 243  Chocolate Chip  245      1.87     458.15
# 244     Whole Wheat   30      3.49      104.7
# 245            Bran   30      1.87       56.1
# 246  Oatmeal Raisin   44      2.84     124.96
#
# [247 rows x 9 columns]

# %% [markdown]
# ## Cases that we should drop
# - merge call
# - actual values = column name

# %%
# Data in case of blank data and merge cell in de_challenge_data.xlsx
df_foodsales[df_foodsales.isnull().any(axis=1)]
# Out:
#        id date region city category product  qty unitprice totalprice
# 122   NaN  NaN    NaN  NaN      NaN     NaN  NaN       NaN        NaN
# 123  2022  NaN    NaN  NaN      NaN     NaN  NaN       NaN        NaN

# %%
# Data that is column name
df_foodsales[df_foodsales['id']=='ID']
# Out:
#      id  date  region  city  category  product  qty  unitprice  totalprice
# 124  ID  Date  Region  City  Category  Product  Qty  UnitPrice  TotalPrice

# %% [markdown]
# ## Drop these cases

# %%
df_foodsales_wo_nan = df_foodsales.dropna(subset=['date'])
df_foodsales_wo_nan
# Out:
#           id                 date region         city  category  \
# 0    ID07351  2022-01-01 00:00:00   East       Boston      Bars
# 1    ID07352  2022-01-04 00:00:00   East       Boston  Crackers
# 2    ID07353  2022-01-07 00:00:00   West  Los Angeles   Cookies
# 3    ID07354  2022-01-10 00:00:00   East     New York   Cookies
# 4    ID07355  2022-01-13 00:00:00   East       Boston   Cookies
# ..       ...                  ...    ...          ...       ...
# 242  ID07590  2023-12-18 00:00:00   East       Boston   Cookies
# 243  ID07591  2023-12-21 00:00:00   East       Boston   Cookies
# 244  ID07592  2023-12-24 00:00:00   East       Boston  Crackers
# 245  ID07593  2023-12-27 00:00:00   West  Los Angeles      Bars
# 246  ID07594  2023-12-30 00:00:00   West  Los Angeles   Cookies
#
#             product  qty unitprice totalprice
# 0            Carrot   33      1.77      58.41
# 1       Whole Wheat   87      3.49     303.63
# 2    Chocolate Chip   58      1.87     108.46
# 3    Chocolate Chip   82      1.87     153.34
# 4         Arrowroot   38      2.18      82.84
# ..              ...  ...       ...        ...
# 242       Arrowroot   34      2.18      74.12
# 243  Chocolate Chip  245      1.87     458.15
# 244     Whole Wheat   30      3.49      104.7
# 245            Bran   30      1.87       56.1
# 246  Oatmeal Raisin   44      2.84     124.96
#
# [245 rows x 9 columns]

# %%
df_foodsales_wo_nan_col = df_foodsales_wo_nan[df_foodsales_wo_nan['id']!='ID']
df_foodsales_wo_nan_col
# Out:
#           id                 date region         city  category  \
# 0    ID07351  2022-01-01 00:00:00   East       Boston      Bars
# 1    ID07352  2022-01-04 00:00:00   East       Boston  Crackers
# 2    ID07353  2022-01-07 00:00:00   West  Los Angeles   Cookies
# 3    ID07354  2022-01-10 00:00:00   East     New York   Cookies
# 4    ID07355  2022-01-13 00:00:00   East       Boston   Cookies
# ..       ...                  ...    ...          ...       ...
# 242  ID07590  2023-12-18 00:00:00   East       Boston   Cookies
# 243  ID07591  2023-12-21 00:00:00   East       Boston   Cookies
# 244  ID07592  2023-12-24 00:00:00   East       Boston  Crackers
# 245  ID07593  2023-12-27 00:00:00   West  Los Angeles      Bars
# 246  ID07594  2023-12-30 00:00:00   West  Los Angeles   Cookies
#
#             product  qty unitprice totalprice
# 0            Carrot   33      1.77      58.41
# 1       Whole Wheat   87      3.49     303.63
# 2    Chocolate Chip   58      1.87     108.46
# 3    Chocolate Chip   82      1.87     153.34
# 4         Arrowroot   38      2.18      82.84
# ..              ...  ...       ...        ...
# 242       Arrowroot   34      2.18      74.12
# 243  Chocolate Chip  245      1.87     458.15
# 244     Whole Wheat   30      3.49      104.7
# 245            Bran   30      1.87       56.1
# 246  Oatmeal Raisin   44      2.84     124.96
#
# [244 rows x 9 columns]
